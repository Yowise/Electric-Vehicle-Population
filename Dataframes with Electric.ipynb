# %% [markdown]
# ## I. Read data from csv file into a pandas dataframe

# %% [markdown]
# #### 1) Import numpy and pandas library and use their standard aliases

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 2) Read in the file

# %% [markdown]
# a) To read in the data, use the `pd.read_csv()` function. The file is called `'electric_vechicle_population.csv'` and is in the working directory. Assign the resuting dataframe to variable called `data`

# %%
data = pd.read_csv('electric_vechicle_population.csv')

# %% [markdown]
# ## II. Summary information

# %% [markdown]
# 1) Use the `info()` method to examine the metadata: the number of rows and columns, the column names, the data type contained in each column, the number of non-null values in each column, and the amount of memory the dataframe uses

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191407 entries, 0 to 191406
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         191407 non-null  object
#  1   County                                             191403 non-null  object
#  2   City                                               191403 non-null  object
#  3   State                                              191407 non-null  object
#  4   Postal Code                                        191403 non-null  float64
#  5   Model Year                                         191407 non-null  int64
#  6   Make                                               191407 non-null  object
#  7   Model                                              191407 non-null  object
#  8   Electric Vehicle Type                              191407 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  191407 non-null  object
#  10  Electric Range                                     191407 non-null  int64
#  11  Base MSRP                                          191407 non-null  int64
#  12  Legislative District                               190993 non-null  float64
#  13  DOL Vehicle ID                                     191407 non-null  int64
#  14  Vehicle Location                                   191399 non-null  object
#  15  Electric Utility                                   191403 non-null  object
#  16  2020 Census Tract                                  191403 non-null  float64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 24.8+ MB

# %% [markdown]
# 2. Use the head() method to retreive the rows of the dataframe

# %%
data.head(10)
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  5YJSA1E22K       King  Seattle    WA      98112.0        2019   TESLA
# 1  3MW39FS05R     Yakima   Zillah    WA      98953.0        2024     BMW
# 2  1N4AZ0CP0F       King     Kent    WA      98031.0        2015  NISSAN
# 3  5YJSA1H20F  Snohomish  Bothell    WA      98012.0        2015   TESLA
# 4  JTMAB3FV1N     Yakima   Yakima    WA      98908.0        2022  TOYOTA
# 5  5YJ3E1EB6K       King  Redmond    WA      98052.0        2019   TESLA
# 6  5YJ3E1EB0J   Thurston     Yelm    WA      98597.0        2018   TESLA
# 7  3FA6P0SU8D     Kitsap  Poulsbo    WA      98370.0        2013    FORD
# 8  5YJSA1E21H       King  Redmond    WA      98052.0        2017   TESLA
# 9  5YJ3E1EA4J  Snohomish  Bothell    WA      98012.0        2018   TESLA
#
#         Model                   Electric Vehicle Type  \
# 0     MODEL S          Battery Electric Vehicle (BEV)
# 1        330E  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     MODEL S          Battery Electric Vehicle (BEV)
# 4  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 5     MODEL 3          Battery Electric Vehicle (BEV)
# 6     MODEL 3          Battery Electric Vehicle (BEV)
# 7      FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 8     MODEL S          Battery Electric Vehicle (BEV)
# 9     MODEL 3          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             270
# 1             Not eligible due to low battery range              20
# 2           Clean Alternative Fuel Vehicle Eligible              84
# 3           Clean Alternative Fuel Vehicle Eligible             208
# 4           Clean Alternative Fuel Vehicle Eligible              42
# 5           Clean Alternative Fuel Vehicle Eligible             220
# 6           Clean Alternative Fuel Vehicle Eligible             215
# 7             Not eligible due to low battery range              19
# 8           Clean Alternative Fuel Vehicle Eligible             210
# 9           Clean Alternative Fuel Vehicle Eligible             215
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  43.0       202233958
# 1          0                  15.0       264425178
# 2          0                  11.0       114962025
# 3          0                   1.0       232724670
# 4          0                  14.0       221023589
# 5          0                  48.0       296777442
# 6          0                   2.0       311913577
# 7          0                  23.0       136752115
# 8          0                  45.0       241259105
# 9          0                   1.0       118035830
#
#                   Vehicle Location  \
# 0    POINT (-122.300312 47.629782)
# 1  POINT (-120.2658133 46.4063477)
# 2    POINT (-122.201564 47.402358)
# 3    POINT (-122.206146 47.839957)
# 4    POINT (-120.611068 46.596645)
# 5  POINT (-122.1207376 47.6705374)
# 6  POINT (-122.5715761 46.9095798)
# 7  POINT (-122.6368884 47.7469547)
# 8  POINT (-122.1207376 47.6705374)
# 9    POINT (-122.206146 47.839957)
#
#                                 Electric Utility  2020 Census Tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 1                                     PACIFICORP       5.307700e+10
# 2  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 3                         PUGET SOUND ENERGY INC       5.306105e+10
# 4                                     PACIFICORP       5.307700e+10
# 5  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 6                         PUGET SOUND ENERGY INC       5.306701e+10
# 7                         PUGET SOUND ENERGY INC       5.303509e+10
# 8  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 9                         PUGET SOUND ENERGY INC       5.306105e+10

# %% [markdown]
# ## III. Clean the data

# %% [markdown]
# #### 1) Convert float to int

# %% [markdown]
# Columns `Postal Code`, `Legislative District` and `2020 Census Tract` have values rendered as float. Given they are discrete units, these codes do not have any decimals. Therefore, they should be converted from `float` to `int`. This is done using method `astype()`.

# %%
data[['Postal Code', 'Legislative District', '2020 Census Tract']] = data[['Postal Code', 'Legislative District', '2020 Census Tract']].fillna(0).astype(int)
data.head(10)
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  5YJSA1E22K       King  Seattle    WA        98112        2019   TESLA
# 1  3MW39FS05R     Yakima   Zillah    WA        98953        2024     BMW
# 2  1N4AZ0CP0F       King     Kent    WA        98031        2015  NISSAN
# 3  5YJSA1H20F  Snohomish  Bothell    WA        98012        2015   TESLA
# 4  JTMAB3FV1N     Yakima   Yakima    WA        98908        2022  TOYOTA
# 5  5YJ3E1EB6K       King  Redmond    WA        98052        2019   TESLA
# 6  5YJ3E1EB0J   Thurston     Yelm    WA        98597        2018   TESLA
# 7  3FA6P0SU8D     Kitsap  Poulsbo    WA        98370        2013    FORD
# 8  5YJSA1E21H       King  Redmond    WA        98052        2017   TESLA
# 9  5YJ3E1EA4J  Snohomish  Bothell    WA        98012        2018   TESLA
#
#         Model                   Electric Vehicle Type  \
# 0     MODEL S          Battery Electric Vehicle (BEV)
# 1        330E  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     MODEL S          Battery Electric Vehicle (BEV)
# 4  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 5     MODEL 3          Battery Electric Vehicle (BEV)
# 6     MODEL 3          Battery Electric Vehicle (BEV)
# 7      FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 8     MODEL S          Battery Electric Vehicle (BEV)
# 9     MODEL 3          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             270
# 1             Not eligible due to low battery range              20
# 2           Clean Alternative Fuel Vehicle Eligible              84
# 3           Clean Alternative Fuel Vehicle Eligible             208
# 4           Clean Alternative Fuel Vehicle Eligible              42
# 5           Clean Alternative Fuel Vehicle Eligible             220
# 6           Clean Alternative Fuel Vehicle Eligible             215
# 7             Not eligible due to low battery range              19
# 8           Clean Alternative Fuel Vehicle Eligible             210
# 9           Clean Alternative Fuel Vehicle Eligible             215
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                    43       202233958
# 1          0                    15       264425178
# 2          0                    11       114962025
# 3          0                     1       232724670
# 4          0                    14       221023589
# 5          0                    48       296777442
# 6          0                     2       311913577
# 7          0                    23       136752115
# 8          0                    45       241259105
# 9          0                     1       118035830
#
#                   Vehicle Location  \
# 0    POINT (-122.300312 47.629782)
# 1  POINT (-120.2658133 46.4063477)
# 2    POINT (-122.201564 47.402358)
# 3    POINT (-122.206146 47.839957)
# 4    POINT (-120.611068 46.596645)
# 5  POINT (-122.1207376 47.6705374)
# 6  POINT (-122.5715761 46.9095798)
# 7  POINT (-122.6368884 47.7469547)
# 8  POINT (-122.1207376 47.6705374)
# 9    POINT (-122.206146 47.839957)
#
#                                 Electric Utility  2020 Census Tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)        53033006500
# 1                                     PACIFICORP        53077002201
# 2  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)        53033029306
# 3                         PUGET SOUND ENERGY INC        53061052107
# 4                                     PACIFICORP        53077000902
# 5  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)        53033022606
# 6                         PUGET SOUND ENERGY INC        53067012422
# 7                         PUGET SOUND ENERGY INC        53035090400
# 8  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)        53033032321
# 9                         PUGET SOUND ENERGY INC        53061052009

# %% [markdown]
# ## III. Explore the data

# %% [markdown]
# #### 1. Select the `Make` column and use the `value_counts()` method on it to check how many rows there are for each `Make` in the dataframe.

# %%
data['Make'].value_counts()
# Out:
# Make
# TESLA                   84670
# CHEVROLET               14321
# NISSAN                  14239
# FORD                    10048
# KIA                      8671
# BMW                      7993
# TOYOTA                   7181
# VOLKSWAGEN               5408
# JEEP                     4996
# HYUNDAI                  4977
# RIVIAN                   4751
# VOLVO                    4469
# AUDI                     3890
# CHRYSLER                 3393
# MERCEDES-BENZ            1784
# PORSCHE                  1182
# MITSUBISHI                996
# MINI                      984
# SUBARU                    970
# POLESTAR                  939
# HONDA                     857
# FIAT                      781
# DODGE                     619
# MAZDA                     581
# LEXUS                     567
# CADILLAC                  552
# LINCOLN                   281
# LUCID                     263
# SMART                     259
# JAGUAR                    234
# GENESIS                   219
# FISKER                    181
# LAND ROVER                 60
# ALFA ROMEO                 56
# GMC                        11
# AZURE DYNAMICS              8
# TH!NK                       5
# WHEEGO ELECTRIC CARS        3
# BENTLEY                     3
# ROLLS ROYCE                 2
# RAM                         2
# ACURA                       1
# Name: count, dtype: int64

# %% [markdown]
# #### 2. Sort by Legislative District

# %%
data_sorted = data.sort_values(by='Legislative District', ascending=False)

# %%
data_sorted.head(10)
# Out:
#        VIN (1-10) County       City State  Postal Code  Model Year       Make  \
# 47238  JTMEB3FV9R  Clark  Vancouver    WA        98686        2024     TOYOTA
# 47236  KNDPYDAH2P  Clark  Vancouver    WA        98661        2023        KIA
# 47247  1G1FW6S06J  Clark  Vancouver    WA        98663        2018  CHEVROLET
# 23895  1C4RJYB61P  Clark  Vancouver    WA        98665        2023       JEEP
# 94643  JTMEB3FV1N  Clark  Vancouver    WA        98663        2022     TOYOTA
# 47220  7SAYGDEE4R  Clark  Vancouver    WA        98665        2024      TESLA
# 47382  1N4AZ1BVXP  Clark  Vancouver    WA        98686        2023     NISSAN
# 74538  JHMZC5F30J  Clark  Vancouver    WA        98661        2018      HONDA
# 74577  1G1FY6S05K  Clark  Vancouver    WA        98661        2019  CHEVROLET
# 74574  KNDRJDLH3N  Clark  Vancouver    WA        98686        2022        KIA
#
#                 Model                   Electric Vehicle Type  \
# 47238      RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 47236        SPORTAGE  Plug-in Hybrid Electric Vehicle (PHEV)
# 47247         BOLT EV          Battery Electric Vehicle (BEV)
# 23895  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 94643      RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 47220         MODEL Y          Battery Electric Vehicle (BEV)
# 47382            LEAF          Battery Electric Vehicle (BEV)
# 74538         CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 74577         BOLT EV          Battery Electric Vehicle (BEV)
# 74574         SORENTO  Plug-in Hybrid Electric Vehicle (PHEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 47238            Clean Alternative Fuel Vehicle Eligible              42
# 47236            Clean Alternative Fuel Vehicle Eligible              34
# 47247            Clean Alternative Fuel Vehicle Eligible             238
# 23895              Not eligible due to low battery range              25
# 94643            Clean Alternative Fuel Vehicle Eligible              42
# 47220  Eligibility unknown as battery range has not b...               0
# 47382  Eligibility unknown as battery range has not b...               0
# 74538            Clean Alternative Fuel Vehicle Eligible              47
# 74577            Clean Alternative Fuel Vehicle Eligible             238
# 74574            Clean Alternative Fuel Vehicle Eligible              32
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 47238          0                    49       264952173
# 47236          0                    49       250999395
# 47247          0                    49       288100473
# 23895          0                    49       259617165
# 94643          0                    49       219143886
# 47220          0                    49       265249218
# 47382          0                    49       245683035
# 74538          0                    49       187649941
# 74577          0                    49       332215600
# 74574          0                    49       207707741
#
#                       Vehicle Location  \
# 47238    POINT (-122.626623 45.711724)
# 47236  POINT (-122.6238365 45.6456491)
# 47247    POINT (-122.657848 45.654422)
# 23895  POINT (-122.6615789 45.6809862)
# 94643    POINT (-122.657848 45.654422)
# 47220  POINT (-122.6615789 45.6809862)
# 47382    POINT (-122.626623 45.711724)
# 74538  POINT (-122.6238365 45.6456491)
# 74577  POINT (-122.6238365 45.6456491)
# 74574    POINT (-122.626623 45.711724)
#
#                                         Electric Utility  2020 Census Tract
# 47238  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040803
# 47236  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011042700
# 47247  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011041800
# 23895  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040809
# 94643  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011041003
# 47220  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040809
# 47382  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040803
# 74538  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011041110
# 74577  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011041112
# 74574  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040808

# %% [markdown]
# #### 3. Use `iloc` to select rows

# %% [markdown]
# Select the two rows at indices 0-9 of the `data_sorted` dataframe

# %%
data_sorted.iloc[0:10]
# Out:
#        VIN (1-10) County       City State  Postal Code  Model Year       Make  \
# 47238  JTMEB3FV9R  Clark  Vancouver    WA        98686        2024     TOYOTA
# 47236  KNDPYDAH2P  Clark  Vancouver    WA        98661        2023        KIA
# 47247  1G1FW6S06J  Clark  Vancouver    WA        98663        2018  CHEVROLET
# 23895  1C4RJYB61P  Clark  Vancouver    WA        98665        2023       JEEP
# 94643  JTMEB3FV1N  Clark  Vancouver    WA        98663        2022     TOYOTA
# 47220  7SAYGDEE4R  Clark  Vancouver    WA        98665        2024      TESLA
# 47382  1N4AZ1BVXP  Clark  Vancouver    WA        98686        2023     NISSAN
# 74538  JHMZC5F30J  Clark  Vancouver    WA        98661        2018      HONDA
# 74577  1G1FY6S05K  Clark  Vancouver    WA        98661        2019  CHEVROLET
# 74574  KNDRJDLH3N  Clark  Vancouver    WA        98686        2022        KIA
#
#                 Model                   Electric Vehicle Type  \
# 47238      RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 47236        SPORTAGE  Plug-in Hybrid Electric Vehicle (PHEV)
# 47247         BOLT EV          Battery Electric Vehicle (BEV)
# 23895  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 94643      RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 47220         MODEL Y          Battery Electric Vehicle (BEV)
# 47382            LEAF          Battery Electric Vehicle (BEV)
# 74538         CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 74577         BOLT EV          Battery Electric Vehicle (BEV)
# 74574         SORENTO  Plug-in Hybrid Electric Vehicle (PHEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 47238            Clean Alternative Fuel Vehicle Eligible              42
# 47236            Clean Alternative Fuel Vehicle Eligible              34
# 47247            Clean Alternative Fuel Vehicle Eligible             238
# 23895              Not eligible due to low battery range              25
# 94643            Clean Alternative Fuel Vehicle Eligible              42
# 47220  Eligibility unknown as battery range has not b...               0
# 47382  Eligibility unknown as battery range has not b...               0
# 74538            Clean Alternative Fuel Vehicle Eligible              47
# 74577            Clean Alternative Fuel Vehicle Eligible             238
# 74574            Clean Alternative Fuel Vehicle Eligible              32
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 47238          0                    49       264952173
# 47236          0                    49       250999395
# 47247          0                    49       288100473
# 23895          0                    49       259617165
# 94643          0                    49       219143886
# 47220          0                    49       265249218
# 47382          0                    49       245683035
# 74538          0                    49       187649941
# 74577          0                    49       332215600
# 74574          0                    49       207707741
#
#                       Vehicle Location  \
# 47238    POINT (-122.626623 45.711724)
# 47236  POINT (-122.6238365 45.6456491)
# 47247    POINT (-122.657848 45.654422)
# 23895  POINT (-122.6615789 45.6809862)
# 94643    POINT (-122.657848 45.654422)
# 47220  POINT (-122.6615789 45.6809862)
# 47382    POINT (-122.626623 45.711724)
# 74538  POINT (-122.6238365 45.6456491)
# 74577  POINT (-122.6238365 45.6456491)
# 74574    POINT (-122.626623 45.711724)
#
#                                         Electric Utility  2020 Census Tract
# 47238  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040803
# 47236  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011042700
# 47247  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011041800
# 23895  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040809
# 94643  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011041003
# 47220  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040809
# 47382  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040803
# 74538  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011041110
# 74577  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011041112
# 74574  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040808

# %% [markdown]
# ### IV. Examine Electric Range data from City Vancouver

# %% [markdown]
# 1. Create a Boolean mask that selects only the observations of the `data_sorted` dataframe at indices 0-9

# %%
mask = data_sorted.iloc[0:10]

# %% [markdown]
# 2. Apply the Boolean mask to the `data_sorted` dataframe and assign the result to a variable called `va_cf`

# %%
va_cf = mask

# %%
va_cf.head(10)
# Out:
#        VIN (1-10) County       City State  Postal Code  Model Year       Make  \
# 47238  JTMEB3FV9R  Clark  Vancouver    WA        98686        2024     TOYOTA
# 47236  KNDPYDAH2P  Clark  Vancouver    WA        98661        2023        KIA
# 47247  1G1FW6S06J  Clark  Vancouver    WA        98663        2018  CHEVROLET
# 23895  1C4RJYB61P  Clark  Vancouver    WA        98665        2023       JEEP
# 94643  JTMEB3FV1N  Clark  Vancouver    WA        98663        2022     TOYOTA
# 47220  7SAYGDEE4R  Clark  Vancouver    WA        98665        2024      TESLA
# 47382  1N4AZ1BVXP  Clark  Vancouver    WA        98686        2023     NISSAN
# 74538  JHMZC5F30J  Clark  Vancouver    WA        98661        2018      HONDA
# 74577  1G1FY6S05K  Clark  Vancouver    WA        98661        2019  CHEVROLET
# 74574  KNDRJDLH3N  Clark  Vancouver    WA        98686        2022        KIA
#
#                 Model                   Electric Vehicle Type  \
# 47238      RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 47236        SPORTAGE  Plug-in Hybrid Electric Vehicle (PHEV)
# 47247         BOLT EV          Battery Electric Vehicle (BEV)
# 23895  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 94643      RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 47220         MODEL Y          Battery Electric Vehicle (BEV)
# 47382            LEAF          Battery Electric Vehicle (BEV)
# 74538         CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 74577         BOLT EV          Battery Electric Vehicle (BEV)
# 74574         SORENTO  Plug-in Hybrid Electric Vehicle (PHEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 47238            Clean Alternative Fuel Vehicle Eligible              42
# 47236            Clean Alternative Fuel Vehicle Eligible              34
# 47247            Clean Alternative Fuel Vehicle Eligible             238
# 23895              Not eligible due to low battery range              25
# 94643            Clean Alternative Fuel Vehicle Eligible              42
# 47220  Eligibility unknown as battery range has not b...               0
# 47382  Eligibility unknown as battery range has not b...               0
# 74538            Clean Alternative Fuel Vehicle Eligible              47
# 74577            Clean Alternative Fuel Vehicle Eligible             238
# 74574            Clean Alternative Fuel Vehicle Eligible              32
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 47238          0                    49       264952173
# 47236          0                    49       250999395
# 47247          0                    49       288100473
# 23895          0                    49       259617165
# 94643          0                    49       219143886
# 47220          0                    49       265249218
# 47382          0                    49       245683035
# 74538          0                    49       187649941
# 74577          0                    49       332215600
# 74574          0                    49       207707741
#
#                       Vehicle Location  \
# 47238    POINT (-122.626623 45.711724)
# 47236  POINT (-122.6238365 45.6456491)
# 47247    POINT (-122.657848 45.654422)
# 23895  POINT (-122.6615789 45.6809862)
# 94643    POINT (-122.657848 45.654422)
# 47220  POINT (-122.6615789 45.6809862)
# 47382    POINT (-122.626623 45.711724)
# 74538  POINT (-122.6238365 45.6456491)
# 74577  POINT (-122.6238365 45.6456491)
# 74574    POINT (-122.626623 45.711724)
#
#                                         Electric Utility  2020 Census Tract
# 47238  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040803
# 47236  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011042700
# 47247  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011041800
# 23895  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040809
# 94643  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011041003
# 47220  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040809
# 47382  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040803
# 74538  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011041110
# 74577  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011041112
# 74574  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...        53011040808

# %% [markdown]
# 3. Calculate the median of the Electric Range of the **previosuly selected cars** in Vancouver

# %%
median_value = round(va_cf['Electric Range'].median())
print(median_value)
# Out:
# 38

# %% [markdown]
# 4. Select **all** the cars in Vancouver that have an Electric Range equal or bigger than 238

# %%
va_big_range = data[(data['Electric Range'] >= 238) & (data['City'] == 'Vancouver')]

# %%
va_big_range['Electric Range'].value_counts()
# Out:
# Electric Range
# 238    133
# 259     67
# 291     65
# 322     45
# 266     40
# 249     32
# 308     25
# 239     24
# 289     19
# 258     19
# 330     14
# 293     13
# 337      7
# 270      6
# 265      3
# Name: count, dtype: int64

# %% [markdown]
# # Congratulations!
